# %%
import numpy as np
import math
from pettingzoo.mpe import simple_tag_v3

from CoordinatingAgent import CoordinatingAgent
from RandomAgent import RandomAgent
from AvoidingAgent import AvoidingAgent
from AvoidingAgentExpert import AvoidingAgentExpert

NUM_GOOD = 1
NUM_ADVERSARIES = 4
NUM_LANDMARKS = 0
MAX_CYCLES = 200

THRESHOLD = 1e-5
DISTANCE_THRESHOLD = 0.5
TARGET_VECT_THRESHOLD = 5

env = simple_tag_v3.parallel_env(num_good=NUM_GOOD, num_adversaries=NUM_ADVERSARIES, num_obstacles=NUM_LANDMARKS, max_cycles=MAX_CYCLES, continuous_actions=False, render_mode="human")
observations, infos = env.reset()

coord_agents = [CoordinatingAgent(name, NUM_ADVERSARIES, NUM_LANDMARKS) for name in env.agents if name != "agent_0"]
# coord_agents.append(RandomAgent("agent_0", NUM_ADVERSARIES, NUM_LANDMARKS))
# coord_agents.append(AvoidingAgent("agent_0", NUM_ADVERSARIES, NUM_LANDMARKS))
coord_agents.append(AvoidingAgentExpert("agent_0", NUM_ADVERSARIES, NUM_LANDMARKS))

for agent in coord_agents:
        agent.observations = observations[agent.name]
        agent.update_observed_agent_positions()

# this implementation assumes one prey only
while env.agents:
    actions = {}
    sum_of_distances_from_target = 0
    for agent in coord_agents:
        actions[agent.name] = agent.get_action()
    observations, rewards, terminations, truncations, infos = env.step(actions)
    print(coord_agents[0].observed_agent_positions["agent_0"])
    for agent in coord_agents:
        agent.observations = observations[agent.name]
        agent.update_observed_agent_positions()

    # print("rewards: ", rewards)

env.close()
# Out:
# Avoiding agent chosen action: 1
# [-0.9705168   0.46081185]
# Avoiding agent chosen action: 1
# [-0.9705168   0.46081185]
# Avoiding agent chosen action: 0
# [-1.0105169   0.46081182]
# Avoiding agent chosen action: 0
# [-1.0805168   0.46081182]
# Avoiding agent chosen action: 2
# [-1.1330168   0.46081185]
# Avoiding agent chosen action: 2
# [-1.1723919   0.46081185]
# Avoiding agent chosen action: 2
# [-1.161923    0.46081182]
# Avoiding agent chosen action: 2
# [-1.1140715   0.46081185]
# Avoiding agent chosen action: 0
# [-1.0381829  0.4608118]
# Avoiding agent chosen action: 1
# [-0.9412663  0.4608119]
# Avoiding agent chosen action: 1
# [-0.868579    0.46081185]
# Avoiding agent chosen action: 1
# [-0.8540634  0.4608118]
# Avoiding agent chosen action: 3
# [-0.8831768  0.4608119]
# Avoiding agent chosen action: 1
# [-0.94501173  0.46081185]
# Avoiding agent chosen action: 1
# [-0.9913881   0.42081177]
# Avoiding agent chosen action: 0
# [-1.0661702  0.3908118]
# Avoiding agent chosen action: 2
# [-1.1622568   0.36831188]
# Avoiding agent chosen action: 2
# [-1.2343218   0.35143673]
# Avoiding agent chosen action: 2
# [-1.2483706   0.33878064]
# Avoiding agent chosen action: 2
# [-1.2189071   0.32928848]
# Avoiding agent chosen action: 2
# [-1.1568096   0.32216918]
# Avoiding agent chosen action: 0
# [-1.0702364   0.31682992]
# Avoiding agent chosen action: 1
# [-0.9653065   0.31282532]
# Avoiding agent chosen action: 3
# [-0.8866091   0.30982202]
# Avoiding agent chosen action: 3
# [-0.86758596  0.30756944]
# Avoiding agent chosen action: 3
# [-0.85331875  0.26588005]
# Avoiding agent chosen action: 3
# [-0.8426183   0.19461298]
# Avoiding agent chosen action: 3
# [-0.8345929   0.10116279]
# Avoiding agent chosen action: 0
# [-0.8285739  -0.00892508]
# Avoiding agent chosen action: 4
# [-0.8240596  -0.13149083]
# Avoiding agent chosen action: 4
# [-0.8206739  -0.22341508]
# Avoiding agent chosen action: 4
# [-0.81813467 -0.25235838]
# Avoiding agent chosen action: 4
# [-0.8162302  -0.23406583]
# Avoiding agent chosen action: 1
# [-0.8148019  -0.18034643]
# Updated target vec divisor: 1.3
# Updated target vec divisor: 1.3
# Updated target vec divisor: 1.3
# Updated target vec divisor: 1.3
# Avoiding agent chosen action: 1
# [-0.8137306  -0.10005683]
# Avoiding agent chosen action: 3
# [-0.85292715 -0.03983968]
# Avoiding agent chosen action: 1
# [-0.92232454  0.00532323]
# Avoiding agent chosen action: 1
# [-9.743726e-01 -8.046031e-04]
# Avoiding agent chosen action: 0
# [-1.0534087  -0.00540054]
# Avoiding agent chosen action: 2
# [-1.1526858  -0.00884742]
# Avoiding agent chosen action: 2
# [-1.2271435  -0.01143259]
# Avoiding agent chosen action: 2
# [-1.2429868  -0.01337153]
# Avoiding agent chosen action: 2
# [-1.2148693 -0.0148257]
# Avoiding agent chosen action: 2
# [-1.1537812  -0.01591629]
# Avoiding agent chosen action: 0
# [-1.0679651  -0.01673424]
# Avoiding agent chosen action: 1
# [-0.963603   -0.01734769]
# Avoiding agent chosen action: 4
# [-0.8853315  -0.01780784]
# Avoiding agent chosen action: 1
# [-0.8666279  -0.01815289]
# Avoiding agent chosen action: 1
# [-0.8526001   0.02158827]
# Updated target vec divisor: 1.6900000000000002
# Updated target vec divisor: 1.6900000000000002
# Updated target vec divisor: 1.6900000000000002
# Updated target vec divisor: 1.6900000000000002
# Avoiding agent chosen action: 1
# [-0.88207924  0.05139416]
# Avoiding agent chosen action: 1
# [-0.94418865  0.07374859]
# Updated target vec divisor: 2.1970000000000005
# Updated target vec divisor: 2.1970000000000005
# Updated target vec divisor: 2.1970000000000005
# Updated target vec divisor: 2.1970000000000005
# Avoiding agent chosen action: 0
# [-1.0307707   0.09051436]
# Avoiding agent chosen action: 2
# [-1.1357071  0.1030888]
# Avoiding agent chosen action: 2
# [-1.2144096   0.11251956]
# Avoiding agent chosen action: 2
# [-1.2334363   0.11959261]
# Avoiding agent chosen action: 2
# [-1.2077066   0.12489742]
# Avoiding agent chosen action: 2
# [-1.1484091   0.12887603]
# Updated target vec divisor: 2.856100000000001
# Updated target vec divisor: 2.856100000000001
# Updated target vec divisor: 2.856100000000001
# Updated target vec divisor: 2.856100000000001
# Avoiding agent chosen action: 0
# [-1.063936    0.13185996]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 1
# [-0.9605812   0.13409793]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 1
# [-0.88306516  0.1357764 ]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 1
# [-0.86492807  0.13703528]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 1
# [-0.89132524  0.13797945]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 1
# [-0.9511231   0.13868752]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 0
# [-1.0359718   0.13921857]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 2
# [-1.1396081   0.13961688]
# Avoiding agent chosen action: 2
# [-1.2173355   0.13991562]
# Avoiding agent chosen action: 2
# [-1.2356309   0.14013964]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 2
# [-1.1071882   0.16020139]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 0
# [-1.0332688   0.24883933]
# Avoiding agent chosen action: 1
# [-0.93782926  0.3153178 ]
# Avoiding agent chosen action: 4
# [-0.8662497   0.36517665]
# Avoiding agent chosen action: 4
# [-0.85256493  0.40257078]
# Avoiding agent chosen action: 4
# [-0.8423013   0.47061637]
# Avoiding agent chosen action: 4
# [-0.83460367  0.5616506 ]
# Avoiding agent chosen action: 4
# [-0.8288304  0.6699263]
# Avoiding agent chosen action: 4
# [-0.8245005  0.7911329]
# Avoiding agent chosen action: 4
# [-0.8212764  0.921093 ]
# Avoiding agent chosen action: 0
# [-0.81899023  1.0510728 ]
# Avoiding agent chosen action: 3
# [-0.817369   1.1810627]
# Avoiding agent chosen action: 3
# [-0.81615305  1.2785552 ]
# Avoiding agent chosen action: 3
# [-0.8152411  1.3116746]
# Avoiding agent chosen action: 3
# [-0.8145572  1.296514 ]
# Avoiding agent chosen action: 3
# [-0.81404424  1.2451437 ]
# Avoiding agent chosen action: 3
# [-0.8136595  1.1666158]
# Avoiding agent chosen action: 0
# [-0.81337094  1.0677199 ]
# Avoiding agent chosen action: 4
# [-0.8131546  0.9535481]
# Avoiding agent chosen action: 3
# [-0.8129923  0.8679192]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 3
# [-0.83100903  0.8809182 ]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 1
# [-0.85999954  0.8314221 ]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 1
# [-0.8817424  0.7543   ]
# Avoiding agent chosen action: 1
# [-0.9380496  0.6964583]
# Avoiding agent chosen action: 0
# [-1.02028    0.6530771]
# Avoiding agent chosen action: 2
# [-1.1219528   0.62054116]
# Avoiding agent chosen action: 2
# [-1.1982073  0.5961393]
# Avoiding agent chosen action: 2
# [-1.2153982  0.5778379]
# Avoiding agent chosen action: 2
# [-1.1882914  0.5641117]
# Avoiding agent chosen action: 2
# [-1.1279614   0.55381715]
# Avoiding agent chosen action: 0
# [-1.0427138  0.5460963]
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Updated target vec divisor: 3
# Avoiding agent chosen action: 1
# [-0.9387781  0.5403055]
# Avoiding agent chosen action: 3
# [-0.8608264  0.5359625]
# Avoiding agent chosen action: 3
# [-0.8470355  0.5297346]
# Avoiding agent chosen action: 3
# [-0.8378565   0.44583967]
# Avoiding agent chosen action: 3
# [-0.8308461   0.31602883]
# Avoiding agent chosen action: 3
# [-0.8258736   0.18612394]
# Avoiding agent chosen action: 3
# [-0.82234716  0.05617177]
# Avoiding agent chosen action: 3
# [-0.81984633 -0.0738042 ]
# Avoiding agent chosen action: 3
# [-0.81807303 -0.20379207]
# Avoiding agent chosen action: 3
# [-0.8168155  -0.33378598]
# Avoiding agent chosen action: 3
# [-0.8159238  -0.46378297]
# Avoiding agent chosen action: 3
# [-0.8152915 -0.5937814]
# Avoiding agent chosen action: 3
# [-0.8148432  -0.72378063]
# Avoiding agent chosen action: 3
# [-0.81452525 -0.85378027]
# Avoiding agent chosen action: 3
# [-0.8142998 -0.98378  ]
# Avoiding agent chosen action: 4
# [-0.81413996 -1.1137799 ]
# Avoiding agent chosen action: 4
# [-0.81402665 -1.2437799 ]
# Avoiding agent chosen action: 4
# [-0.8139416 -1.3012798]
# Avoiding agent chosen action: 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 37
#      35 for agent in coord_agents:
#      36     actions[agent.name] = agent.get_action()
# ---> 37 observations, rewards, terminations, truncations, infos = env.step(actions)
#      38 print(coord_agents[0].observed_agent_positions["agent_0"])
#      39 for agent in coord_agents:
#
# File ~/.local/lib/python3.10/site-packages/pettingzoo/utils/conversions.py:207, in aec_to_parallel_wrapper.step(self, actions)
#     203         raise AssertionError(
#     204             f"expected agent {agent} got agent {self.aec_env.agent_selection}, Parallel environment wrapper expects agents to step in a cycle."
#     205         )
#     206 obs, rew, termination, truncation, info = self.aec_env.last()
# --> 207 self.aec_env.step(actions[agent])
#     208 for agent in self.aec_env.agents:
#     209     rewards[agent] += self.aec_env.rewards[agent]
#
# File ~/.local/lib/python3.10/site-packages/pettingzoo/utils/wrappers/order_enforcing.py:96, in OrderEnforcingWrapper.step(self, action)
#      94 else:
#      95     self._has_updated = True
# ---> 96     super().step(action)
#
# File ~/.local/lib/python3.10/site-packages/pettingzoo/utils/wrappers/base.py:47, in BaseWrapper.step(self, action)
#      46 def step(self, action: ActionType) -> None:
# ---> 47     self.env.step(action)
#
# File ~/.local/lib/python3.10/site-packages/pettingzoo/utils/wrappers/assert_out_of_bounds.py:26, in AssertOutOfBoundsWrapper.step(self, action)
#      16 def step(self, action: ActionType) -> None:
#      17     assert (
#      18         action is None
#      19         and (
#    (...)
#      24         action
#      25     ), "action is not in action space"
# ---> 26     super().step(action)
#
# File ~/.local/lib/python3.10/site-packages/pettingzoo/utils/wrappers/base.py:47, in BaseWrapper.step(self, action)
#      46 def step(self, action: ActionType) -> None:
# ---> 47     self.env.step(action)
#
# File ~/.local/lib/python3.10/site-packages/pettingzoo/mpe/_mpe_utils/simple_env.py:264, in SimpleEnv.step(self, action)
#     261 self._accumulate_rewards()
#     263 if self.render_mode == "human":
# --> 264     self.render()
#
# File ~/.local/lib/python3.10/site-packages/pettingzoo/mpe/_mpe_utils/simple_env.py:287, in SimpleEnv.render(self)
#     285 elif self.render_mode == "human":
#     286     pygame.display.flip()
# --> 287     self.clock.tick(self.metadata["render_fps"])
#     288     return
#
# KeyboardInterrupt:

# %%
env.close()
